# %% [markdown]
# <a href="https://colab.research.google.com/github/catherinegrc/ITBA3204-PROJECT-PROPOSAL-ERAP/blob/main/povertydata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns
import plotly as py
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
import plotly.graph_objs as go

# %%
url = 'https://raw.githubusercontent.com/catherinegrc/ITBA3204-PROJECT-PROPOSAL-ERAP/main/consolidated_philippines_poverty_data.csv'
df = pd.read_csv(url)
newdf = df.drop([0,1,2], axis=0)
newdf.rename(columns={'Current Real Minimum Wage Based on February 2022 CPI (2018=100)': 'Region','Unnamed: 1': 'NonAgriculture', 'Unnamed: 2': 'AgriculturePlantation', 'Unnamed: 3': 'AgricultureNonPlantation'}, inplace=True)

display(newdf.iloc[0:])
# Out:
#                 regDesc  agr_wage_farm_workers_allgender_2015  \
# 3            Calabarzon                                230.92
# 4                   Car                                206.68
# 5                Caraga                                194.46
# 6         Central Luzon                                257.97
# 7       Central Visayas                                156.17
# 8          Davao Region                                168.68
# 9       Eastern Visayas                                157.49
# 10        Ilocos Region                                237.26
# 11             Mimaropa                                188.73
# 12    Northern Mindanao                                159.12
# 13         Soccsksargen                                164.77
# 14      Western Visayas                                165.28
# 15  Zamboanga Peninsula                                157.37
#
#     agr_wage_farm_workers_male_2015  agr_wage_farm_workers_female_2015  \
# ...

# %%
newdf.hist(figsize=(20,20))
plt.show()

# %%
ax = sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
# Out:
# <ipython-input-21-f836a3d34f84>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
